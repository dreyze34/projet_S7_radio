# %%
#Changer le répertoire courant pour l'import des modules
import os

current_dir = os.getcwd()

target_dir = os.path.abspath(os.path.join(current_dir, '..'))

os.chdir(target_dir)

# %%
from ApplicationsUNet.loadData import ThoraxDataLoader
import SimpleITK as sitk
import numpy as np  
import matplotlib.pyplot as plt

# %%
loader = ThoraxDataLoader("./Data/Data_Medical/MCsimulations")
dataset = loader.load_all_samples("HS")


print(type(dataset))
# Out:
# sample_0011 chargé avec succès.
# sample_0016 chargé avec succès.
# sample_0018 chargé avec succès.
# sample_0019 chargé avec succès.
# sample_0020 chargé avec succès.
# sample_0026 chargé avec succès.
# sample_0027 chargé avec succès.
# sample_0029 chargé avec succès.
# sample_0042 chargé avec succès.
# sample_0043 chargé avec succès.
# sample_0044 chargé avec succès.
# sample_0045 chargé avec succès.
# sample_0072 chargé avec succès.
# sample_0073 chargé avec succès.
# sample_0074 chargé avec succès.
# sample_0075 chargé avec succès.
# sample_0080 chargé avec succès.
# sample_0081 chargé avec succès.
# sample_0086 chargé avec succès.
# sample_0087 chargé avec succès.
# sample_0088 chargé avec succès.
# sample_0089 chargé avec succès.
# sample_0212 chargé avec succès.
# sample_0214 chargé avec succès.
# sample_0215 chargé avec succès.
# sample_0223 chargé avec succès.
# sample_0224 chargé avec succès.
# sample_0240 chargé avec succès.
# sample_0241 chargé avec succès.
# ...

# %%
newcmp = loader.newcmp

# %%
print (dataset.shape)

exemple = dataset[0]
print(exemple.shape)
# Out:
# (658, 64, 64)
# (64, 64)

# %%
plt.imshow(exemple, cmap = newcmp)

# %%
exemple_flat = exemple.flatten().reshape(-1,1)
exemple_flat.shape
# Out:
# (4096, 1)

# %%
from sklearn.mixture import GaussianMixture

# %%
gmm = GaussianMixture(n_components=4, random_state=44)
gmm.fit(exemple_flat)


clusters = gmm.predict(exemple_flat)

segmented_exemple = clusters.reshape(exemple.shape)

# %%
#affichage
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(segmented_exemple, cmap="viridis")
plt.show()
plt.subplot(1,2,2)
plt.imshow(exemple, cmap=newcmp)
plt.show()
